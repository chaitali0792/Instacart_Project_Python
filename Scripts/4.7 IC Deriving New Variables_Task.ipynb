# %% [markdown]
# # CONTENT LIST
# 1. Import Libraries
# 2. Importing Data
# 3. Creating new column for range of the products
# 4. Creating new column to check busiest day of week
# 5. Beginning of Task 7
# 6. Export data

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data

# %%
# Creating common folder path
path = r'C:\Users\Mukund\Desktop\Career Foundry\Instacart_Grocery_Basket_Analysis_May_2021'

# %%
# Importing orders_products_merged dataframe
df_ords_prods_merged  = pd.read_pickle(os.path.join(path, 'Data', 'Prepared_data', 'Orders_Products_Merged.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  add_to_cart_order  reordered  user_id  order_number  \
# 0      1107                  7          0    38259             2
# 1      5319                  3          1   196224            65
# 2      7540                  4          1   138499             8
# 3      9228                  2          0    79603             2
# 4      9273                 30          0    50005             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order _merge
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 14)

# %%
df_ords_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int64
#  1   product_name            object
#  2   aisle_id                int64
#  3   department_id           int64
#  4   prices                  float64
#  5   order_id                int64
#  6   add_to_cart_order       int16
#  7   reordered               int8
#  8   user_id                 int64
#  9   order_number            int64
#  10  orders_day_of_week      int8
#  11  order_hour_of_day       int8
#  12  days_since_prior_order  int16
#  13  _merge                  category
# dtypes: category(1), float64(1), int16(2), int64(6), int8(3), object(1)
# memory usage: 2.4+ GB

# %%
# Creating subset of first 1 million rows
df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # 3. Creating new column for range of the products

# %%
# Defining function of price range
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Applying the price_label function function on subset of merged data
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-10-f3349ed18d37>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Checking the count of price range
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
# Checking the maximum price of product from subset
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# Using the loc function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range products'
# Out:
# C:\Users\Mukund\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Mukund\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\Mukund\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\Mukund\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Checking the count of products with price range from loc function
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product      652638
# Low-range product      338018
# High-range products      9344
# Name: price_range_loc, dtype: int64

# %%
# Applying loc function on whole dataframe 'High-range products'
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range products'

# %%
# 'Mid-range products'
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# 'Low-range products'
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                    21208222
# Low-range product      10126321
# Mid-range product        652638
# High-range products      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 4. Creating new column to check busiest day of week

# %%
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# If statement with for loop

# %%
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Creating new column in dataframe
df_ords_prods_merged['Busiest_Day'] = result

# %%
# Checking the count of busiest days
df_ords_prods_merged['Busiest_Day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest_Day, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  add_to_cart_order  reordered  user_id  order_number  \
# 0      1107                  7          0    38259             2
# 1      5319                  3          1   196224            65
# 2      7540                  4          1   138499             8
# 3      9228                  2          0    79603             2
# 4      9273                 30          0    50005             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order _merge  \
# ...

# %% [markdown]
# # 5. Beginning of Task 7

# %% [markdown]
# Step 1) If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns. >> Done above

# %% [markdown]
# Step 2) Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# From 'orders_day_of_week' count, we know that Sunday(0) and Monday(1) has the highest count of orders and Thursday (4) and Wednesday(3)

# %%
# Getting the busiest days and slowest days from dataframe
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest days")
  elif value == 1:
    result.append("Busiest days")
  elif value == 4:
    result.append("Slowest days")
  elif value == 3:
    result.append("Slowest days")
  else:
    result.append("Regular days")

# %%
result
# Out:
# ['Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Regular days',
#  'Slowest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
# ...

# %%
# Creating new column in dataframe
df_ords_prods_merged['Busiest_Days'] = result

# %%
# Checking the count of Busiest_Days 
df_ords_prods_merged['Busiest_Days'].value_counts(dropna = False)
# Out:
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest_Days, dtype: int64

# %% [markdown]
# Step 3) Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
df_ords_prods_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  add_to_cart_order  reordered  user_id  \
# ...

# %% [markdown]
# Step 4) When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# checking the busiest hour of day
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# defining results for most, average and fewest hours of the day
result = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in (10, 11, 14, 15, 13, 12, 16, 9):
    result.append("Most orders")
  elif value in (17, 8, 18, 19, 20, 7, 21, 22):
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
# Creating new column in dataframe
df_ords_prods_merged['busiest_period_of_day'] = result

# %%
df_ords_prods_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  add_to_cart_order  reordered  user_id  \
# ...

# %% [markdown]
# Step 5) Print the frequency for this new column.

# %%
# Checking the count of busiest_period_of_day 
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# Step 7) Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
df_ords_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   product_id              int64
#  1   product_name            object
#  2   aisle_id                int64
#  3   department_id           int64
#  4   prices                  float64
#  5   order_id                int64
#  6   add_to_cart_order       int16
#  7   reordered               int8
#  8   user_id                 int64
#  9   order_number            int64
#  10  orders_day_of_week      int8
#  11  order_hour_of_day       int8
#  12  days_since_prior_order  int16
#  13  _merge                  category
#  14  price_range_loc         object
#  15  Busiest_Day             object
#  16  Busiest_Days            object
#  17  busiest_period_of_day   object
# dtypes: category(1), float64(1), int16(2), int64(6), int8(3), object(5)
# memory usage: 4.4+ GB

# %%
df_ords_prods_merged['user_id'].unique()
# Out:
# array([ 38259, 196224, 138499, ...,  27382,  56454,  74506], dtype=int64)

# %% [markdown]
# # 6. Export data

# %%
# Exporting dataframe with newly added columns in pkl format
df_ords_prods_merged.to_pickle(os.path.join(path,'Data','Prepared_data','orders_products_merged_with_columns.pkl'))
